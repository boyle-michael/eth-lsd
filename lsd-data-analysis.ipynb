# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read in the CSV file using Pandas
df = pd.read_csv('lsd-data.csv')

# Set the first column as the index
# df = df.set_index(df.columns[0])

# Create a line plot for each column compared to the first column
for column in df.columns:
    if column != df.columns[0]:
        plt.plot(df.index, df[column], label=column)

        # Add a legend and axis labels
        plt.legend()
        plt.xlabel(df.columns[0])
        plt.ylabel('Value')

        # Show the plot
        plt.show()

# %%
df
# Out:
#                Timestamp   ethereum price   rocket-pool-eth exchange rate
# 0    2023-04-28 14:02:33          1894.46                        1.067930  \
# 1    2023-04-28 14:03:34          1894.46                        1.067930
# 2    2023-04-28 14:04:34          1894.46                        1.067930
# 3    2023-04-28 14:05:35          1894.46                        1.067930
# 4    2023-04-28 14:06:36          1894.46                        1.067930
# ..                   ...              ...                             ...
# 575  2023-04-28 23:46:59          1903.36                        1.068043
# 576  2023-04-28 23:48:00          1903.36                        1.068043
# 577  2023-04-28 23:49:01          1903.36                        1.068043
# 578  2023-04-28 23:50:02          1903.36                        1.068043
# 579  2023-04-28 23:51:03          1903.36                        1.068043
#
#       rocket-pool-eth expected price   rocket-pool-eth actual price
# 0                        2023.149745                        2022.79  \
# 1                        2023.149745                        2022.79
# 2                        2023.149745                        2022.79
# 3                        2023.149745                        2022.79
# 4                        2023.149745                        2022.79
# ..                               ...                            ...
# 575                      2032.869940                        2034.27
# 576                      2032.869940                        2034.27
# 577                      2032.869940                        2034.27
# 578                      2032.869940                        2034.27
# 579                      2032.869940                        2034.27
#
#       rocket-pool-eth deviation   wrapped-steth exchange rate
# 0                     -0.017785                      1.120971  \
# 1                     -0.017785                      1.120971
# 2                     -0.017785                      1.120971
# 3                     -0.017785                      1.120971
# 4                     -0.017785                      1.120971
# ..                          ...                           ...
# 575                    0.068824                      1.120971
# 576                    0.068824                      1.120971
# 577                    0.068824                      1.120971
# 578                    0.068824                      1.120971
# 579                    0.068824                      1.120971
#
#       wrapped-steth expected price   wrapped-steth actual price
# 0                      2123.634217                      2119.75  \
# 1                      2123.634217                      2119.75
# 2                      2123.634217                      2119.75
# 3                      2123.634217                      2119.75
# 4                      2123.634217                      2119.75
# ..                             ...                          ...
# 575                    2133.610857                      2132.11
# 576                    2133.610857                      2132.11
# 577                    2133.610857                      2132.11
# 578                    2133.610857                      2132.11
# 579                    2133.610857                      2132.11
#
#       wrapped-steth deviation   frax-ether exchange rate
# 0                   -0.183239                   1.036145  \
# 1                   -0.183239                   1.036145
# 2                   -0.183239                   1.036145
# 3                   -0.183239                   1.036146
# 4                   -0.183239                   1.036146
# ..                        ...                        ...
# 575                 -0.070393                   1.036222
# 576                 -0.070393                   1.036222
# 577                 -0.070393                   1.036222
# 578                 -0.070393                   1.036222
# 579                 -0.070393                   1.036222
#
#       frax-ether expected price   frax-ether actual price
# 0                   1962.935589                   1893.03  \
# 1                   1962.935838                   1893.03
# 2                   1962.936087                   1893.03
# 3                   1962.936336                   1893.03
# 4                   1962.936585                   1893.03
# ..                          ...                       ...
# 575                 1972.302999                   1902.29
# 576                 1972.303245                   1902.29
# 577                 1972.303540                   1902.29
# 578                 1972.303737                   1902.29
# 579                 1972.304032                   1902.29
#
#       frax-ether deviation
# 0                -3.692788
# 1                -3.692801
# 2                -3.692815
# 3                -3.692828
# 4                -3.692841
# ..                     ...
# 575              -3.680459
# 576              -3.680472
# 577              -3.680487
# 578              -3.680498
# 579              -3.680513
#
# [580 rows x 14 columns]
